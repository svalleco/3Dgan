# %%
import tensorflow as tf
print(tf.__version__)
#python -c "import tensorflow as tf;print(tf.__version__)"
# Out:
# 2.2.0

# %%
#Select GPU 0 or 1
GPU = 0      # Or 0,1, 2, 3, etc.
import os
os.environ["CUDA_VISIBLE_DEVICES"] = str(GPU)  

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print(os.getcwd())  #print path
# Out:
# Num GPUs Available:  1
# /eos/home-f/frehm/TF2/Skripts/F02-03/Runs/Conv2D/GitHub scripts/Conv2D_1_branch_residual

# %%
#set parameters
save_folder = "TF_K_1"         #Name of the Folder in which the results schould be safed

train_file_by_file = True              #True if you want to import the trainingsdata file by file
train_on_folder = False                #True if you want to train on all data files within this folder, False if you want to train just with one file
train_data_path = "/eos/home-f/frehm/TF2/Data/EleEscan_1_1/EleEscan_1_1.h5" #file
train_folder_path = "/eos/home-f/frehm/TF2/Data//"     #there has to be a folder inside
train_file_by_file_path = "/data/frehm/File_by_file/"                  #data on GPU

lrate_g = 0.0005
lrate_d = 0.00010   #lr_d should be roughly the same as the ratio from g to d parameters
nb_epochs = 30
percent = 100                      #take just 10 percent of all data for training and testing
nb_train_files = 20           #20
ReLU_epoch = 3
save_only_best_weights = True
latent_size = 200
batch_size =  128                   #128     #batch_size must be less or equal test size, otherwise error
keras_dformat = 'channels_last'    #last for CPU, first for GPU
wtf = 6.0                           #weight true fake loss
wa = 0.2                            #weight auxiliary loss
we = 0.1                            #weight ecal loss


from PTF_m1_2_fullK_1path_residual import *
from Functions_v1_5_6 import *

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from __future__ import print_function
from collections import defaultdict
try:
    import cPickle as pickle
except ImportError:
    import pickle
import argparse
import os
from six.moves import range
import sys
import h5py 
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import time
import math as math

# %%
generator(keras_dformat=keras_dformat).summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 125)          25125       input_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 5, 5, 5)      0           dense[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 5, 5, 32)     4000        reshape[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 5, 5, 32)     0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 5, 5, 32)     128         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 5, 5, 32)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 15, 15, 64)   51264       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 15, 15, 64)   102400      conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 15, 15, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 15, 15, 64)   256         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 15, 15, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 30, 30, 64)   102464      dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 25, 25, 64)   147456      conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 25, 25, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 25, 25, 64)   256         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 25, 25, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 25, 64)   331776      dropout_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 25, 25, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 25, 25, 64)   256         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 25, 25, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 25, 25, 64)   200704      dropout_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 25, 25, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 25, 25, 64)   256         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 25, 25, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 25, 25, 64)   102400      dropout_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 25, 25, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 25, 25, 64)   256         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 25, 25, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 64)   102400      dropout_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 25, 25, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 64)   256         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 25, 25, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 32)   32768       dropout_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 25, 25, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 32)   128         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 25, 25, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 25)   12800       dropout_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 25, 25, 25)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 25)   100         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 25, 25, 25)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 25, 25, 25)   0           dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 64)   129600      permute[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 25, 25, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 64)   256         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 25, 25, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 25, 25, 64)   200704      dropout_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 64)   102400      dropout_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 64)   102400      dropout_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 32)   32768       dropout_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 25, 25, 32)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 32)   128         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 25, 25, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 25)   12800       dropout_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 25, 25, 25)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 25)   100         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 25, 25, 25)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 25, 25, 25)   0           dropout_8[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 25, 25, 25)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   129600      permute_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 64)   200704      dropout_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 64)   102400      dropout_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 64)   102400      dropout_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 32)   32768       dropout_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 25, 25, 32)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 32)   128         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 25, 25, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 25, 25, 25)   12800       dropout_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 25, 25, 25)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 25)   100         leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 25, 25, 25)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 25, 25, 25)   0           dropout_8[0][0]
#                                                                  dropout_14[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 25, 25, 25)   10000       add_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 25, 25, 25)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 25)   100         leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 25, 25, 25)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 25, 25, 25)   5625        dropout_21[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 25, 25, 25, 1 0           conv2d_22[0][0]
# ==================================================================================================
# Total params: 2,397,022
# Trainable params: 2,394,774
# Non-trainable params: 2,248
# __________________________________________________________________________________________________

# %%
discriminator(keras_dformat=keras_dformat).summary()
# Out:
# (None, 9, 9, 9)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 25, 25, 25,  0
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 25, 25, 25)   0           input_2[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 25, 25, 25)   0           reshape_2[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 25, 25, 25)   0           reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 25, 25, 64)   102400      permute_2[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 25, 25, 64)   102400      permute_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 25, 25, 64)   102400      reshape_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 25, 25, 64)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 64)   256         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 25, 25, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 20, 20, 32)   73728       dropout_31[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 20, 20, 32)   73728       dropout_40[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 20, 20, 32)   73728       dropout_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 20, 20, 32)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 20, 20, 32)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 20, 20, 32)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 20, 20, 32)   128         leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 20, 20, 32)   128         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 20, 20, 32)   128         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 20, 20, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 20, 20, 32)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 20, 20, 32)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 32)   25600       dropout_32[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 32)   25600       dropout_41[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 32)   25600       dropout_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 16, 16, 32)   0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 16, 16, 32)   0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 16, 16, 32)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 32)   128         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 32)   128         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 32)   128         leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 16, 16, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 16, 16, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 16, 16, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 13, 13, 32)   16384       dropout_33[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 13, 13, 32)   16384       dropout_42[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 13, 13, 32)   16384       dropout_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 13, 13, 32)   36864       dropout_34[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 13, 13, 32)   36864       dropout_43[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 13, 13, 32)   36864       dropout_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 13, 13, 32)   16384       dropout_35[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 13, 13, 32)   16384       dropout_44[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 13, 13, 32)   16384       dropout_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 13, 13, 32)   9216        dropout_36[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 13, 13, 32)   9216        dropout_45[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 13, 13, 32)   9216        dropout_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 13, 13, 32)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 13, 13, 32)   128         leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 13, 13, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 11, 11, 32)   9216        dropout_37[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 11, 11, 32)   9216        dropout_46[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 11, 11, 32)   9216        dropout_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 11, 11, 32)   0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 11, 11, 32)   0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 11, 11, 32)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 11, 11, 32)   128         leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 11, 11, 32)   128         leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 11, 11, 32)   128         leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 11, 11, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 11, 11, 32)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 11, 11, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 9, 9, 9)      2592        dropout_38[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 9, 9, 9)      2592        dropout_47[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 9, 9, 9)      2592        dropout_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 9, 9, 9)      0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 9, 9, 9)      0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 9, 9, 9)      0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 9, 9, 9)      36          leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 9, 9, 9)      36          leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 9, 9, 9)      36          leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 9, 9, 9)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 9, 9, 9)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 9, 9, 9)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 9, 9, 9)      0           dropout_39[0][0]
# __________________________________________________________________________________________________
# permute_5 (Permute)             (None, 9, 9, 9)      0           dropout_48[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 9, 9, 27)     0           dropout_30[0][0]
#                                                                  permute_4[0][0]
#                                                                  permute_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2187)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           21880       flatten[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 10)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 10)           40          leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# generation (Dense)              (None, 1)            11          batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# auxiliary (Dense)               (None, 1)            11          batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           input_2[0][0]
# ==================================================================================================
# Total params: 902,658
# Trainable params: 900,856
# Non-trainable params: 1,802
# __________________________________________________________________________________________________

# %%
#create output folders for saving files and weights
create_folder(save_folder+'/')
create_folder(save_folder+'/Weights/')
create_folder(save_folder+'/Weights/disc')
create_folder(save_folder+'/Weights/gen')
create_folder(save_folder+'/Pickle/')
create_folder(save_folder+'/Save_Images/')
print('*************************************************************************************')

#import trainingsdata
if train_file_by_file == False:
    X,y = import_data(train_on_folder, train_data_path, train_folder_path)
    print('*************************************************************************************') 

    #do data preperation    
    X_train, X_test, y_train, y_test, ecal_train, ecal_test, nb_train, nb_test = data_preperation(X, y, keras_dformat, batch_size, percent)
    y_train = np.expand_dims(y_train, axis=-1)  #macht jeden Eintrag in der Liste zu einer Unterliste [1,2,3]->[[1],[2],[3]]
    y_test  = np.expand_dims(y_test,  axis=-1)
    X_train = tf.constant(X_train)
    X_test  = tf.constant(X_test)
    y_train = np.expand_dims(y_train, axis=-1)  #macht jeden Eintrag in der Liste zu einer Unterliste [1,2,3]->[[1],[2],[3]]
    y_test  = np.expand_dims(y_test,  axis=-1)
    y_train = tf.constant(y_train)
    y_test  = tf.constant(y_test)
    ecal_train = tf.constant(ecal_train)
    ecal_test  = tf.constant(ecal_test)
    print("X_train_shape: ", X_train.shape)
    print("X_test_shape: ", X_test.shape)
    print("ecal_train_shape: ", ecal_train.shape)
    print("ecal_test_shape: ", ecal_test.shape)
    print('*************************************************************************************')
else:
    files = create_files_list(train_file_by_file_path)
    X_test = []
    y_test = []
    ecal_test = []
# Out:
# Directory  TF_K_1/  Created
# Directory  TF_K_1/Weights/  Created
# Directory  TF_K_1/Weights/disc  Created
# Directory  TF_K_1/Weights/gen  Created
# Directory  TF_K_1/Pickle/  Created
# Directory  TF_K_1/Save_Images/  Created
# *************************************************************************************

# %%
#discriminator.build()
discriminator = discriminator(keras_dformat = keras_dformat)
generator = generator(keras_dformat = keras_dformat, latent_size = 200)
#generator = tf.saved_model.load(save_folder + "/Generator")
#print(discriminator.trainable_variables)
#print(generator.trainable_variables)
# Out:
# (None, 9, 9, 9)

# %%
#load best weights
#load_path = "/eos/home-f/frehm/TF2/Skripts/F02-03/Runs/Conv2D/Optuna/v4_5_briderparameterrange/Search_1/Trial_8/"
#epoch = str(7)
#gweights = load_path + "Weights/gen/params_generator_epoch_" + epoch + ".hdf5"
#dweights = load_path + "Weights/disc/params_discriminator_epoch_"+ epoch +".hdf5"
#generator.load_weights(gweights)
#discriminator.load_weights(dweights)

# %%
#define plots during training after each epoch

#%matplotlib notebook            #this is for 3D projection
epoch=0

#function for plotting a training images
if train_file_by_file == False:
    plot_images(X, epoch, save_folder, save=False, number=1)

def plot_gen_image_tf(latent_size, epoch=0):   #generate a image 
    tf.random.set_seed(1)     
    noise, gen_aux, generator_input, gen_ecal = func_for_gen(1,latent_size=latent_size)
    tf.random.set_seed(None)
    generated_images = generator(generator_input)
    try:
        generated_images = np.squeeze(generated_images, axis=(1,))
    except:
        generated_images = np.squeeze(generated_images, axis=(-1,))
    Xgen = generated_images
    plot_images(Xgen, epoch, save_folder, save=True, number=1)
    return

plot_gen_image_tf(latent_size)

# %%
#learningrate decay with epochs
def l_dec(initial_lrate, epoch, start_decay=80, decay_rate=0.012):
    epoch = epoch - 1 #because training starts at epoch 1
    if epoch < start_decay:
        k = 0.0
    else:
        k = decay_rate #0.07
        epoch = epoch - start_decay
    lrate = initial_lrate * math.exp(-k*epoch)
    return lrate

ep_list=[]
lr_list=[]
for i in range(1,nb_epochs*20):
    ep_list.append(i)
    lr_list.append(l_dec(lrate_g, i))
ep_list = [i / 20 for i in ep_list]

plt.plot(ep_list,lr_list)
plt.title("Learningrate Decay")
plt.xlabel("Epochs")
plt.ylabel("Learnrate")
plt.show()
print("lr last value: ", round(lr_list[-1],5))
#print(lr_list)
# Out:
# lr last value:  0.0

# %%
#run validation script
#validation_metric = validate(generator, percent=10, keras_dformat=keras_dformat, data_path=train_file_by_file_path)

# %%
#Gromov-Wasserstein Validation
#https://github.com/svalleco/3Dgan/blob/Anglegan/keras/misc/GromovWass.py#L287

#Gromov_Wasserstein_distance = analyse(generator, read_data=False, save_data=False, gen_weights="", data_path=train_file_by_file_path,
#       sorted_path="", optimizer = Gromov_metric)
#print('Gromov-Wasserstein distances: ' + str(Gromov_Wasserstein_distance))

# %%
#training
verbose = 'true'

train_history = defaultdict(list)   #create a dict with an empty list 
test_history = defaultdict(list)

start_epoch = 1             #i want to start traing at epoch 1
for epoch in range(start_epoch, nb_epochs + 1):
    print('Epoch {} of {}'.format(epoch, nb_epochs))
    start_epoch = time.time()
    lr_d = l_dec(lrate_d, epoch)
    lr_g = l_dec(lrate_g, epoch)
    optimizer_d = tf.optimizers.Adam(lr_d)
    optimizer_g = tf.optimizers.Adam(lr_g)
    #nb_batches = int(X_train.shape[0] / batch_size)
    epoch_gen_loss = []
    epoch_disc_loss = []

    if 'X_test' in locals() and train_file_by_file == True:
        del X_test
        del y_test
        del ecal_test
    if train_file_by_file == False:
        files = [1]

    #Iterate over the number of trainingsfiles
    for file_number in range(nb_train_files):

        #import data file by file method
        if train_file_by_file == True:
            start_import = time.time()
            print("File: ", file_number+1, "/", nb_train_files)
            X, y = train_file_by_file_import(train_file_by_file_path, files, file_number)
            X_train, X_test_file, y_train, y_test_file, ecal_train, ecal_test_file, nb_train, nb_test = data_preperation(X, y, keras_dformat, batch_size, percent)
            y_train = np.expand_dims(y_train, axis=-1)  #macht jeden Eintrag in der Liste zu einer Unterliste [1,2,3]->[[1],[2],[3]]
            y_test_file = np.expand_dims(y_test_file, axis=-1)
            if 'X_test' in locals():
                X_test = np.concatenate((X_test, X_test_file))
                y_test = np.concatenate((y_test, y_test_file))
                ecal_test = np.concatenate((ecal_test, ecal_test_file))
            else: 
                X_test = X_test_file
                y_test = y_test_file
                ecal_test = ecal_test_file
            nb_test=len(y_test)
            end_import = time.time()
            e2 = int(end_import-start_import)
            print('Time for Import: {:02d}:{:02d}:{:02d}'.format(e2 // 3600, (e2 % 3600 // 60), e2 % 60))

            lr_d = l_dec(lrate_d, epoch*20+file_number-20)
            lr_g = l_dec(lrate_g, epoch*20+file_number-20)
            optimizer_d = tf.optimizers.Adam(lr_d)
            optimizer_g = tf.optimizers.Adam(lr_g)
        print("Learnrate Generator:     ", lr_g)
        print("Learnrate Discriminator: ", lr_d)
        nb_batches = int(X_train.shape[0] / batch_size)
        if verbose:
            progress_bar = tf.keras.utils.Progbar(target=nb_batches)
        ################################################################################

        #training; loop over epochs
        for batch in range(nb_batches):
            if verbose:
                progress_bar.update(batch+1)
            else:
                if epoch % 100 == 0:
                    print('processed {}/{} batches'.format(batch + 1, nb_batches))

            #create batches
            image_batch  = X_train[(batch*batch_size) : ((batch+1)*batch_size)]
            energy_batch = y_train[(batch*batch_size) : ((batch+1)*batch_size)]
            ecal_batch   = ecal_train[(batch*batch_size) : ((batch+1)*batch_size)]

            #discriminator true training
            with tf.GradientTape(watch_accessed_variables=False) as tape:
                tape.watch(discriminator.trainable_variables)
                d_loss_true = disc_loss(generator, discriminator, image_batch, energy_batch, ecal_batch, batch_size, label ="ones", wtf=wtf, wa=wa, we=we)
                d_grads = tape.gradient( d_loss_true[0] , discriminator.trainable_variables )
            optimizer_d.apply_gradients( zip( d_grads , discriminator.trainable_variables) )

            #discriminator fake training
            with tf.GradientTape(watch_accessed_variables=False) as tape:
                tape.watch(discriminator.trainable_variables)
                noise, gen_aux, generator_input, gen_ecal = func_for_gen(nb_test=batch_size, epoch=epoch) 
                generated_images = generator(generator_input)
                d_loss_fake = disc_loss(generator, discriminator, generated_images, gen_aux, gen_ecal, batch_size, label = "zeros", wtf=wtf, wa=wa, we=we)
                d_grads = tape.gradient( d_loss_fake[0] , discriminator.trainable_variables )
            optimizer_d.apply_gradients( zip( d_grads , discriminator.trainable_variables) )
            d_loss = []
            d_loss.append( (d_loss_true[0] + d_loss_fake[0])/2)
            d_loss.append( (d_loss_true[1] + d_loss_fake[1])/2)
            d_loss.append( (d_loss_true[2] + d_loss_fake[2])/2)
            d_loss.append( (d_loss_true[3] + d_loss_fake[3])/2)
            epoch_disc_loss.append([d_loss[0].numpy(), d_loss[1].numpy(), d_loss[2].numpy(), d_loss[3].numpy()])  

            #generator training
            gen_losses = []
            for i in range(1):
                with tf.GradientTape(watch_accessed_variables=False) as tape:
                    tape.watch(generator.trainable_variables)
                    g_loss = gen_loss(generator, discriminator, batch_size=batch_size, epoch=epoch, wtf=wtf, wa=wa, we=we)
                    g_grads = tape.gradient( g_loss[0] , generator.trainable_variables )
                optimizer_g.apply_gradients( zip( g_grads , generator.trainable_variables ) )
                gen_losses.append([g_loss[0].numpy(), g_loss[1].numpy(), g_loss[2].numpy(), g_loss[3].numpy()])
            epoch_gen_loss.append(np.mean(gen_losses, axis = 0))
    ################################################################################
    #testing
    nb_batches = int(X_test.shape[0] / batch_size)
    if nb_batches == 0:  #I need this or I get an error if I reduce the data with percentage
        nb_batches = 1
    disc_test_loss_list = []
    gen_test_loss_list = []
    for batch in range(nb_batches):
        #create batches
        image_batch  = X_test[(batch*batch_size) : ((batch+1)*batch_size)]
        energy_batch = y_test[(batch*batch_size) : ((batch+1)*batch_size)]
        ecal_batch   = ecal_test[(batch*batch_size) : ((batch+1)*batch_size)]

        d_test_loss_true = disc_loss(generator, discriminator, image_batch, energy_batch, ecal_batch, batch_size, label ="ones", wtf=wtf, wa=wa, we=we)
        noise, gen_aux, generator_input, gen_ecal = func_for_gen(nb_test=batch_size, epoch=epoch) 
        generated_images = generator(generator_input)
        d_test_loss_fake = disc_loss(generator, discriminator, generated_images, gen_aux, gen_ecal, batch_size, label = "zeros", wtf=wtf, wa=wa, we=we)
        d_test_loss = []
        d_test_loss.append( (d_test_loss_true[0] + d_test_loss_fake[0])/2)
        d_test_loss.append( (d_test_loss_true[1] + d_test_loss_fake[1])/2)
        d_test_loss.append( (d_test_loss_true[2] + d_test_loss_fake[2])/2)
        d_test_loss.append( (d_test_loss_true[3] + d_test_loss_fake[3])/2)
        disc_test_loss_list.append([d_test_loss[0].numpy(), d_test_loss[1].numpy(), d_test_loss[2].numpy(), d_test_loss[3].numpy()])

        gen_test_loss = gen_loss(generator, discriminator, batch_size)
        gen_test_loss_list.append([gen_test_loss[0].numpy(), gen_test_loss[1].numpy(), gen_test_loss[2].numpy(), gen_test_loss[3].numpy()])

    ###############################
    #validation script
    validation_metric = validate(generator, percent=percent, keras_dformat=keras_dformat, data_path=train_file_by_file_path)
    Gromov_Wasserstein_distance = analyse(generator, read_data=False, save_data=False, gen_weights="", data_path=train_file_by_file_path,
       sorted_path="", optimizer = Gromov_metric)
    ##############################
    #loss dict
    discriminator_train_loss = np.mean(np.array(epoch_disc_loss), axis=0)   #mean disc loss for all epochs
    generator_train_loss = np.mean(np.array(epoch_gen_loss), axis=0)
    discriminator_test_loss = np.mean(np.array(disc_test_loss_list), axis=0)
    generator_test_loss = np.mean(np.array(gen_test_loss_list), axis=0)

    train_history['generator'].append(generator_train_loss)
    train_history['discriminator'].append(discriminator_train_loss)
    train_history['validation'].append(validation_metric)
    train_history['Gromov_Wasserstein_validation'].append(Gromov_Wasserstein_distance)
    test_history['generator'].append(generator_test_loss)
    test_history['discriminator'].append(discriminator_test_loss)
    end_d = time.time()

    #calculate time for epoch
    end_batch = time.time()
    e = int(end_batch-start_epoch)
    print('Time for Epoch: {:02d}:{:02d}:{:02d}'.format(e // 3600, (e % 3600 // 60), e % 60))

    #save history
    pickle.dump([train_history, test_history], open(save_folder+'/Pickle/3dgan-history.pkl', 'wb'))
    pickle.dump({'train': train_history, 'test': test_history}, open(save_folder+'/Pickle/3dgan-history_dict.pkl', 'wb'))

    #print loss table and plot generated image; also save them
    loss_table(train_history, test_history, save_folder, epoch, validation_metric, save=True, timeforepoch = e)
    plot_loss(train_history, test_history, save_folder, save=True)
    plot_validation(train_history, save_folder)
    plot_gromov_w_distance(train_history, save_folder)

    #dump data
    if epoch >=13:
        generator.save_weights(save_folder+"/Weights/gen/params_generator_epoch_"+str(epoch)+".hdf5",overwrite=True)
        discriminator.save_weights(save_folder+"/Weights/disc/params_discriminator_epoch_"+str(epoch)+".hdf5",overwrite=True)

    #plot of generated image
    plot_gen_image_tf(latent_size, epoch)
# Out:
# Epoch 1 of 30
# File:  1 / 20
# Time for Import: 00:00:07
# Learnrate Generator:      0.0005
# Learnrate Discriminator:  0.0001
# 70/70 [==============================] - 23s 324ms/step
